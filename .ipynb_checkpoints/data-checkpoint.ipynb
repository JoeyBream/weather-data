# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
weather_data = r'C:\Users\JosephBream\OneDrive - Smart Managed Solutions\Documents\Weather Station Data.xlsx'

# Read all sheets into a dictionary of DataFrames
dfs = pd.read_excel(weather_data, sheet_name=None)

# Iterate over each sheet and write it to a CSV file
# for sheet_name, df in dfs.items():
#     csv_filename = f"{sheet_name}.csv"  # Construct the CSV filename
#     df.to_csv(csv_filename, index=False)  # Write DataFrame to CSV without index

#     print(f"Converted '{sheet_name}' to CSV: {csv_filename}")

# %%
WS_Data = pd.read_csv('Data.csv')
WS_Stations = pd.read_csv('Stations.csv')

# %%
WS_Data.head() # Quick look at the data
# Out:
#     Timestamp  03770H150  03770C150  EGLLH150  EGLLC150  EGLCH150  EGLCC150
# 0  2010-01-01      375.7        0.0     397.5       0.0     385.6       0.0
# 1  2010-02-01      292.9        0.0     307.8       0.0     305.8       0.0
# 2  2010-03-01      228.5        0.1     246.5       0.3     241.7       0.1
# 3  2010-04-01      134.7       10.0     147.1       9.7     150.8       7.9
# 4  2010-05-01      104.7       28.6     114.7      31.5     116.5      23.0

# %%
WS_Stations.head() #  A look at the stations records
# Out:
#   Station ID          Station Name Station Longitude Station Latitude  \
# 0      03770  London St James Park             0.13W           51.50N
# 1       EGLL            London, GB             0.45W           51.48N
# 2       EGLC   London City Airport               NaN              NaN
#
#   Station City  % Estimated
# 0       London        0.020
# 1       London        0.002
# 2       London        0.030

# %%
# Some data cleaning
WS_Data['Timestamp'] = pd.to_datetime(WS_Data['Timestamp'])

# %%
## HEATING DEGREE DAY PER MONTH ##
fig1 = plt.figure()
x = WS_Data['Timestamp']
y = WS_Data['03770H150']
chart = plt.plot(x, y, color="darkorange")
plt.title("Heating degree days per month, 2010 - 2024")
plt.tight_layout()
plt.xlabel("Timestamp")
plt.ylabel("Cooling degree days")
plt.show()

# %%
## COOLING DEGREE DAY PER MONTH ##
fig2 = plt.figure()
x = WS_Data['Timestamp']
y = WS_Data['03770C150']
plt.plot(x, y, color="turquoise")
plt.title("Heating degree days per month, 2010 - 2024")
plt.tight_layout()
plt.xlabel("Timestamp")
plt.ylabel("Cooling degree days")
plt.show()

# %%
# Add a column displaying the year
WS_Data['Year'] = WS_Data["Timestamp"].dt.year

# Grouping the data by year
WS_Data_ByYear = WS_Data.groupby(['Year']).mean().reset_index() # Use reset_index so that columns keep their names

# %%
## HEATING DEGREE DAYS PER YEAR ## (Using Matplotlib)
fig3 = plt.figure()
x = WS_Data_ByYear['Year']
y = WS_Data_ByYear['03770H150']
chart = plt.bar(x, y, color="darkorange")
plt.title("Heating degree days per year, 2010 - 2024")
plt.tight_layout()
plt.xlabel("Timestamp")
plt.ylabel("Heating degree days")
plt.show()

# %%
## COOLING DEGREE DAYS PER YEAR ## (Using Matplotlib)
fig4 = plt.figure()
x = WS_Data_ByYear['Year']
y = WS_Data_ByYear['03770C150']
chart = plt.bar(x, y, color="turquoise")
plt.title("Cooling degree days per year, 2010 - 2024")
plt.tight_layout()
plt.xlabel("Timestamp")
plt.ylabel("Cooling degree days")
plt.show()

# %% [markdown]
# ### Month-by-month comparison
# <p> Next, let's compare the same month over several years. Recently, September heatwaves have become much more common, so we will look at these first.
#
# Then, let's consider whether March is getting warmer also.

# %%
# Slice data to only give March from each year
WS_Data_March = WS_Data[WS_Data['Timestamp'].dt.month == 3]
WS_Data_March.head()
# Out:
#     Timestamp  03770H150  03770C150  EGLLH150  EGLLC150  EGLCH150  EGLCC150  \
# 2  2010-03-01      228.5        0.1     246.5       0.3     241.7       0.1
# 14 2011-03-01      215.7        1.4     230.9       1.5     230.0       0.8
# 26 2012-03-01      168.2        6.7     187.2       7.2     182.9       4.3
# 38 2013-03-01      333.2        0.1     346.3       0.1     354.2       0.1
# 50 2014-03-01      177.4        6.0     191.7       5.3     173.9       5.0
#
#     Year
# 2   2010
# 14  2011
# 26  2012
# 38  2013
# 50  2014

# %%
## HEATING DEGREE DAYS EACH MARCH ## (Using Matplotlib)
fig5 = plt.figure()
x = WS_Data_March['Year']
y = WS_Data_March['03770H150']
chart = plt.bar(x, y, color="darkorange")
plt.title("Heating degree days in March, 2010 - 2024")
plt.tight_layout()
plt.xlabel("Timestamp")
plt.ylabel("Heating degree days")
plt.show()

# %% [markdown]
# <b> Discussion of above chart
# <p> Well, we are seeing an average reduction in the number of heating degree days each March for this weather station in London. <br>
#     This is generally in line with perceived trends. The month of March is less cold, UK Winters are shorter than previously.

# %%
# Slice data to only give September from each year
WS_Data_Sept = WS_Data[WS_Data['Timestamp'].dt.month == 9]
WS_Data_Sept.head()
# Out:
#     Timestamp  03770H150  03770C150  EGLLH150  EGLLC150  EGLCH150  EGLCC150  \
# 8  2010-09-01       34.0       38.3      46.0      37.5      32.7      35.5
# 20 2011-09-01       20.5       63.5      25.8      59.4      15.5      70.8
# 32 2012-09-01       45.2       43.0      53.3      43.6      38.8      46.2
# 44 2013-09-01       36.0       42.3      41.0      45.6      27.7      46.9
# 56 2014-09-01       14.4       71.5      19.8      69.5      10.6      71.0
#
#     Year
# 8   2010
# 20  2011
# 32  2012
# 44  2013
# 56  2014

# %%
## COOLING DEGREE DAYS EACH SEPTEMBER ## (Using Matplotlib)
fig5 = plt.figure()
x = WS_Data_Sept['Year']
y = WS_Data_Sept['03770C150']
chart = plt.bar(x, y, color="turquoise")
plt.title("Cooling degree days in September, 2010 - 2024")
plt.tight_layout()
plt.xlabel("Timestamp")
plt.ylabel("Cooling degree days")
plt.show()

# %% [markdown]
# <b> Discussion of above chart
# <p> We see an increase in the number of cooling degree days each September for this weather station in London. <br>
#     This means that chillers in buildings will be using more energy, since buildings will get hotter and rely more on AC units. <br>
#     This is generally in line with perceived trends. The month of March is less cold, UK Winters are shorter than previously. <br>
#     In our company, we will have to find ways to combat this increased use of AC, by finding other efficiencies
